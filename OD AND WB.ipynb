# %%
# Comparative Study of OD AND WB
import pandas as pd 
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib.colors import ListedColormap
import itertools
import warnings
import glob ,os 
import statsmodels.api as sm
from sklearn import linear_model

# %%
Odisha=pd.read_csv("Odisha.csv")
Odisha
# Out:
#       Year   GAV Agri   GAV Manf   GAV Cons     GAV Ind  GAV Banking
# 0      NaN        NaN        NaN        NaN         NaN          NaN  \
# 1   2011.0  2555039.0  4116404.0  2059629.0   9600472.0     796303.0
# 2   2012.0  3153542.0  3985120.0  2009633.0   9516379.0     898381.0
# 3   2013.0  2864360.0  4830204.0  2144855.0  11060447.0     929172.0
# 4   2014.0  3154054.0  4374503.0  2138636.0  10284597.0    1018384.0
# 5   2015.0  2454137.0  4840719.0  2146416.0  11767248.0    1097064.0
# 6   2016.0  3025226.0  6449059.0  2300759.0  14119724.0    1065757.0
# 7   2017.0  2417149.0  7773873.0  2493035.0  15244684.0    1152675.0
# 8   2018.0  2622730.0  9214682.0  2592606.0  17067231.0    1212766.0
# 9   2019.0  3133176.0  8154216.0  2597656.0  15884212.0    1316548.0
# 10  2020.0  3459517.0  8639034.0  2325975.0  15676017.0    1388623.0
# 11  2021.0  3183534.0  9838713.0  2496845.0  17561060.0    1525796.0
#
#     GAV Services  GDP/Capita
# 0            NaN         NaN
# 1      8488159.0  23098708.0
# 2      9117405.0  24336348.0
# 3      9827201.0  26589153.0
# 4     10588381.0  27066534.0
# 5     11585388.0  29222893.0
# 6     12047474.0  33734806.0
# 7     13101089.0  36111668.0
# 8     13459199.0  38673286.0
# 9     14465107.0  39799217.0
# 10    13101052.0  38147033.0
# 11    14165748.0  42033322.0

# %%
WB=pd.read_csv("WestBengal.csv")
WB
# Out:
#       Year   GAV Agri    GAV Manf   GAV Cons     GAV Ind  GAV Banking
# 0      NaN        NaN         NaN        NaN         NaN          NaN  \
# 1   2011.0  7245329.0   6952409.0  4440021.0  13251365.0    3194965.0
# 2   2012.0  7539404.0   6969505.0  4586293.0  13565591.0    3484158.0
# 3   2013.0  7401140.0   6994457.0  5047938.0  14090806.0    3302705.0
# 4   2014.0  7914584.0   6423027.0  5012952.0  13595862.0    3522773.0
# 5   2015.0  7858815.0   7805565.0  4533856.0  14670805.0    3760460.0
# 6   2016.0  8055480.0   9089555.0  5746116.0  17146911.0    3917706.0
# 7   2017.0  8470069.0  10135979.0  5968809.0  18628587.0    4079512.0
# 8   2018.0  8459381.0  11917620.0  6334469.0  20875835.0    4087314.0
# 9   2019.0  8522533.0  12606494.0  6976082.0  22334728.0    4245160.0
# 10  2020.0  9010712.0  11636588.0  7646374.0  22114958.0    3428793.0
# 11  2021.0        NaN         NaN        NaN         NaN          NaN
#
#     GAV Services  GDP/Capita
# 0            NaN         NaN
# 1     24885034.0  52048504.0
# 2     26295613.0  54219069.0
# 3     27547464.0  55849707.0
# 4     29362695.0  57436434.0
# 5     31254696.0  60954467.0
# 6     32864839.0  65341593.0
# 7     35109536.0  69498032.0
# 8     37172005.0  73908186.0
# 9     40048954.0  78442406.0
# 10    40284245.0  79272009.0
# 11           NaN         NaN

# %%
Odisha.shape
# Out:
# (12, 8)

# %%
WB.shape
# Out:
# (12, 8)

# %%
Odisha.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          11 non-null     float64
#  1   GAV Agri      11 non-null     float64
#  2   GAV Manf      11 non-null     float64
#  3   GAV Cons      11 non-null     float64
#  4   GAV Ind       11 non-null     float64
#  5   GAV Banking   11 non-null     float64
#  6   GAV Services  11 non-null     float64
#  7   GDP/Capita    11 non-null     float64
# dtypes: float64(8)
# memory usage: 900.0 bytes

# %%
WB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          11 non-null     float64
#  1   GAV Agri      10 non-null     float64
#  2   GAV Manf      10 non-null     float64
#  3   GAV Cons      10 non-null     float64
#  4   GAV Ind       10 non-null     float64
#  5   GAV Banking   10 non-null     float64
#  6   GAV Services  10 non-null     float64
#  7   GDP/Capita    10 non-null     float64
# dtypes: float64(8)
# memory usage: 900.0 bytes

# %%
mean_gdp=Odisha['GDP/Capita'].mean()
mean_gdp
# Out:
# 32619360.727272727

# %%
mean_gdp=WB['GDP/Capita'].mean()
mean_gdp
# Out:
# 64697040.7

# %%
std_gdp=Odisha['GDP/Capita'].std()
std_gdp
# Out:
# 6773499.939178668

# %%
std_gdp=WB['GDP/Capita'].std()
std_gdp
# Out:
# 10134906.039101211

# %%
# GDP growth rate 
Odisha['Growth Rate']=Odisha['GDP/Capita'].pct_change()*100
Odisha
# Out:
#       Year   GAV Agri   GAV Manf   GAV Cons     GAV Ind  GAV Banking
# 0      NaN        NaN        NaN        NaN         NaN          NaN  \
# 1   2011.0  2555039.0  4116404.0  2059629.0   9600472.0     796303.0
# 2   2012.0  3153542.0  3985120.0  2009633.0   9516379.0     898381.0
# 3   2013.0  2864360.0  4830204.0  2144855.0  11060447.0     929172.0
# 4   2014.0  3154054.0  4374503.0  2138636.0  10284597.0    1018384.0
# 5   2015.0  2454137.0  4840719.0  2146416.0  11767248.0    1097064.0
# 6   2016.0  3025226.0  6449059.0  2300759.0  14119724.0    1065757.0
# 7   2017.0  2417149.0  7773873.0  2493035.0  15244684.0    1152675.0
# 8   2018.0  2622730.0  9214682.0  2592606.0  17067231.0    1212766.0
# 9   2019.0  3133176.0  8154216.0  2597656.0  15884212.0    1316548.0
# 10  2020.0  3459517.0  8639034.0  2325975.0  15676017.0    1388623.0
# 11  2021.0  3183534.0  9838713.0  2496845.0  17561060.0    1525796.0
#
#     GAV Services  GDP/Capita  Growth Rate
# 0            NaN         NaN          NaN
# 1      8488159.0  23098708.0          NaN
# 2      9117405.0  24336348.0     5.358049
# 3      9827201.0  26589153.0     9.256956
# 4     10588381.0  27066534.0     1.795398
# 5     11585388.0  29222893.0     7.966883
# 6     12047474.0  33734806.0    15.439652
# 7     13101089.0  36111668.0     7.045726
# 8     13459199.0  38673286.0     7.093602
# 9     14465107.0  39799217.0     2.911392
# 10    13101052.0  38147033.0    -4.151298
# 11    14165748.0  42033322.0    10.187657

# %%
# GDP growth rate 
WB['Growth Rate']=WB['GDP/Capita'].pct_change()*100
WB
# Out:
#       Year   GAV Agri    GAV Manf   GAV Cons     GAV Ind  GAV Banking
# 0      NaN        NaN         NaN        NaN         NaN          NaN  \
# 1   2011.0  7245329.0   6952409.0  4440021.0  13251365.0    3194965.0
# 2   2012.0  7539404.0   6969505.0  4586293.0  13565591.0    3484158.0
# 3   2013.0  7401140.0   6994457.0  5047938.0  14090806.0    3302705.0
# 4   2014.0  7914584.0   6423027.0  5012952.0  13595862.0    3522773.0
# 5   2015.0  7858815.0   7805565.0  4533856.0  14670805.0    3760460.0
# 6   2016.0  8055480.0   9089555.0  5746116.0  17146911.0    3917706.0
# 7   2017.0  8470069.0  10135979.0  5968809.0  18628587.0    4079512.0
# 8   2018.0  8459381.0  11917620.0  6334469.0  20875835.0    4087314.0
# 9   2019.0  8522533.0  12606494.0  6976082.0  22334728.0    4245160.0
# 10  2020.0  9010712.0  11636588.0  7646374.0  22114958.0    3428793.0
# 11  2021.0        NaN         NaN        NaN         NaN          NaN
#
#     GAV Services  GDP/Capita  Growth Rate
# 0            NaN         NaN          NaN
# 1     24885034.0  52048504.0          NaN
# 2     26295613.0  54219069.0     4.170274
# 3     27547464.0  55849707.0     3.007499
# 4     29362695.0  57436434.0     2.841066
# 5     31254696.0  60954467.0     6.125090
# 6     32864839.0  65341593.0     7.197382
# 7     35109536.0  69498032.0     6.361092
# 8     37172005.0  73908186.0     6.345725
# 9     40048954.0  78442406.0     6.134936
# 10    40284245.0  79272009.0     1.057595
# 11           NaN         NaN     0.000000

# %%
Avg_Growth_Rate=Odisha['Growth Rate'].mean()
Avg_Growth_Rate
# Out:
# 6.290401642044289

# %%
Avg_Growth_Rate=WB['Growth Rate'].mean()
Avg_Growth_Rate
# Out:
# 4.324065877834307

# %%
null_values=Odisha.isnull().sum()
print(null_values)
# Out:
# Year            1
# GAV Agri        1
# GAV Manf        1
# GAV Cons        1
# GAV Ind         1
# GAV Banking     1
# GAV Services    1
# GDP/Capita      1
# Growth Rate     2
# dtype: int64

# %%
#Finding Null values 
null_values=WB.isnull().sum()
print(null_values)
# Out:
# Year            1
# GAV Agri        2
# GAV Manf        2
# GAV Cons        2
# GAV Ind         2
# GAV Banking     2
# GAV Services    2
# GDP/Capita      2
# Growth Rate     2
# dtype: int64

# %%
#Deleting the 0th row
Odisha=Odisha.drop(0)
Odisha
# Out:
#       Year   GAV Agri   GAV Manf   GAV Cons     GAV Ind  GAV Banking
# 1   2011.0  2555039.0  4116404.0  2059629.0   9600472.0     796303.0  \
# 2   2012.0  3153542.0  3985120.0  2009633.0   9516379.0     898381.0
# 3   2013.0  2864360.0  4830204.0  2144855.0  11060447.0     929172.0
# 4   2014.0  3154054.0  4374503.0  2138636.0  10284597.0    1018384.0
# 5   2015.0  2454137.0  4840719.0  2146416.0  11767248.0    1097064.0
# 6   2016.0  3025226.0  6449059.0  2300759.0  14119724.0    1065757.0
# 7   2017.0  2417149.0  7773873.0  2493035.0  15244684.0    1152675.0
# 8   2018.0  2622730.0  9214682.0  2592606.0  17067231.0    1212766.0
# 9   2019.0  3133176.0  8154216.0  2597656.0  15884212.0    1316548.0
# 10  2020.0  3459517.0  8639034.0  2325975.0  15676017.0    1388623.0
# 11  2021.0  3183534.0  9838713.0  2496845.0  17561060.0    1525796.0
#
#     GAV Services  GDP/Capita  Growth Rate
# 1      8488159.0  23098708.0          NaN
# 2      9117405.0  24336348.0     5.358049
# 3      9827201.0  26589153.0     9.256956
# 4     10588381.0  27066534.0     1.795398
# 5     11585388.0  29222893.0     7.966883
# 6     12047474.0  33734806.0    15.439652
# 7     13101089.0  36111668.0     7.045726
# 8     13459199.0  38673286.0     7.093602
# 9     14465107.0  39799217.0     2.911392
# 10    13101052.0  38147033.0    -4.151298
# 11    14165748.0  42033322.0    10.187657

# %%
#Deleting the 0th row
WB=WB.drop(0)
WB
# Out:
#       Year   GAV Agri    GAV Manf   GAV Cons     GAV Ind  GAV Banking
# 1   2011.0  7245329.0   6952409.0  4440021.0  13251365.0    3194965.0  \
# 2   2012.0  7539404.0   6969505.0  4586293.0  13565591.0    3484158.0
# 3   2013.0  7401140.0   6994457.0  5047938.0  14090806.0    3302705.0
# 4   2014.0  7914584.0   6423027.0  5012952.0  13595862.0    3522773.0
# 5   2015.0  7858815.0   7805565.0  4533856.0  14670805.0    3760460.0
# 6   2016.0  8055480.0   9089555.0  5746116.0  17146911.0    3917706.0
# 7   2017.0  8470069.0  10135979.0  5968809.0  18628587.0    4079512.0
# 8   2018.0  8459381.0  11917620.0  6334469.0  20875835.0    4087314.0
# 9   2019.0  8522533.0  12606494.0  6976082.0  22334728.0    4245160.0
# 10  2020.0  9010712.0  11636588.0  7646374.0  22114958.0    3428793.0
# 11  2021.0        NaN         NaN        NaN         NaN          NaN
#
#     GAV Services  GDP/Capita  Growth Rate
# 1     24885034.0  52048504.0          NaN
# 2     26295613.0  54219069.0     4.170274
# 3     27547464.0  55849707.0     3.007499
# 4     29362695.0  57436434.0     2.841066
# 5     31254696.0  60954467.0     6.125090
# 6     32864839.0  65341593.0     7.197382
# 7     35109536.0  69498032.0     6.361092
# 8     37172005.0  73908186.0     6.345725
# 9     40048954.0  78442406.0     6.134936
# 10    40284245.0  79272009.0     1.057595
# 11           NaN         NaN     0.000000

# %%
#Handling Missing Values 
# Interpolation
Odisha['GAV Agri']=Odisha['GAV Agri'].interpolate()
Odisha['GAV Manf']=Odisha['GAV Manf'].interpolate()
Odisha['GAV Cons']=Odisha['GAV Cons'].interpolate()
Odisha['GAV Ind']=Odisha['GAV Ind'].interpolate()
#maha['GAV banking']=maha['GAV banking'].interpolate()
Odisha['GAV Services']=Odisha['GAV Services'].interpolate()
Odisha['GDP/Capita']=Odisha['GDP/Capita'].interpolate()
Odisha['Growth Rate']=Odisha['Growth Rate'].interpolate()
Odisha['GAV Banking ']=Odisha['GAV Banking'].interpolate()
Odisha
# Out:
#       Year   GAV Agri   GAV Manf   GAV Cons     GAV Ind  GAV Banking
# 1   2011.0  2555039.0  4116404.0  2059629.0   9600472.0     796303.0  \
# 2   2012.0  3153542.0  3985120.0  2009633.0   9516379.0     898381.0
# 3   2013.0  2864360.0  4830204.0  2144855.0  11060447.0     929172.0
# 4   2014.0  3154054.0  4374503.0  2138636.0  10284597.0    1018384.0
# 5   2015.0  2454137.0  4840719.0  2146416.0  11767248.0    1097064.0
# 6   2016.0  3025226.0  6449059.0  2300759.0  14119724.0    1065757.0
# 7   2017.0  2417149.0  7773873.0  2493035.0  15244684.0    1152675.0
# 8   2018.0  2622730.0  9214682.0  2592606.0  17067231.0    1212766.0
# 9   2019.0  3133176.0  8154216.0  2597656.0  15884212.0    1316548.0
# 10  2020.0  3459517.0  8639034.0  2325975.0  15676017.0    1388623.0
# 11  2021.0  3183534.0  9838713.0  2496845.0  17561060.0    1525796.0
#
#     GAV Services  GDP/Capita  Growth Rate  GAV Banking
# 1      8488159.0  23098708.0          NaN      796303.0
# 2      9117405.0  24336348.0     5.358049      898381.0
# 3      9827201.0  26589153.0     9.256956      929172.0
# 4     10588381.0  27066534.0     1.795398     1018384.0
# 5     11585388.0  29222893.0     7.966883     1097064.0
# 6     12047474.0  33734806.0    15.439652     1065757.0
# 7     13101089.0  36111668.0     7.045726     1152675.0
# 8     13459199.0  38673286.0     7.093602     1212766.0
# 9     14465107.0  39799217.0     2.911392     1316548.0
# 10    13101052.0  38147033.0    -4.151298     1388623.0
# 11    14165748.0  42033322.0    10.187657     1525796.0

# %%
#Handling Missing Values 
# Interpolation
WB['GAV Agri']=WB['GAV Agri'].interpolate()
WB['GAV Manf']=WB['GAV Manf'].interpolate()
WB['GAV Cons']=WB['GAV Cons'].interpolate()
WB['GAV Ind']=WB['GAV Ind'].interpolate()
#maha['GAV banking']=maha['GAV banking'].interpolate()
WB['GAV Services']=WB['GAV Services'].interpolate()
WB['GDP/Capita']=WB['GDP/Capita'].interpolate()
WB['Growth Rate']=WB['Growth Rate'].interpolate()
WB['GAV Banking']=WB['GAV Banking'].interpolate()
WB
# Out:
#       Year   GAV Agri    GAV Manf   GAV Cons     GAV Ind  GAV Banking
# 1   2011.0  7245329.0   6952409.0  4440021.0  13251365.0    3194965.0  \
# 2   2012.0  7539404.0   6969505.0  4586293.0  13565591.0    3484158.0
# 3   2013.0  7401140.0   6994457.0  5047938.0  14090806.0    3302705.0
# 4   2014.0  7914584.0   6423027.0  5012952.0  13595862.0    3522773.0
# 5   2015.0  7858815.0   7805565.0  4533856.0  14670805.0    3760460.0
# 6   2016.0  8055480.0   9089555.0  5746116.0  17146911.0    3917706.0
# 7   2017.0  8470069.0  10135979.0  5968809.0  18628587.0    4079512.0
# 8   2018.0  8459381.0  11917620.0  6334469.0  20875835.0    4087314.0
# 9   2019.0  8522533.0  12606494.0  6976082.0  22334728.0    4245160.0
# 10  2020.0  9010712.0  11636588.0  7646374.0  22114958.0    3428793.0
# 11  2021.0  9010712.0  11636588.0  7646374.0  22114958.0    3428793.0
#
#     GAV Services  GDP/Capita  Growth Rate
# 1     24885034.0  52048504.0          NaN
# 2     26295613.0  54219069.0     4.170274
# 3     27547464.0  55849707.0     3.007499
# 4     29362695.0  57436434.0     2.841066
# 5     31254696.0  60954467.0     6.125090
# 6     32864839.0  65341593.0     7.197382
# 7     35109536.0  69498032.0     6.361092
# 8     37172005.0  73908186.0     6.345725
# 9     40048954.0  78442406.0     6.134936
# 10    40284245.0  79272009.0     1.057595
# 11    40284245.0  79272009.0     0.000000

# %%
# Covariance of different variable with respect to GDP/Capita

# %%
cov_Agri=Odisha['GAV Agri'].cov(Odisha['GDP/Capita'])
cov_Agri
# Out:
# 571374202404.9272

# %%
cov_Agri=WB['GAV Agri'].cov(WB['GDP/Capita'])
cov_Agri
# Out:
# 6201525058319.337

# %%
cov_Manf=Odisha['GAV Manf'].cov(Odisha['GDP/Capita'])
cov_Manf
# Out:
# 14698944341619.248

# %%
cov_Manf=WB['GAV Manf'].cov(WB['GDP/Capita'])
cov_Manf
# Out:
# 24271666747861.93

# %%
cov_Cons=Odisha['GAV Cons'].cov(Odisha['GDP/Capita'])
cov_Cons
# Out:
# 1362702719101.3638

# %%
cov_Cons=WB['GAV Cons'].cov(WB['GDP/Capita'])
cov_Cons
# Out:
# 12252736054035.338

# %%
cov_Ind=Odisha['GAV Ind'].cov(Odisha['GDP/Capita'])
cov_Ind
# Out:
# 20433051926669.82

# %%
cov_Ind=WB['GAV Ind'].cov(WB['GDP/Capita'])
cov_Ind
# Out:
# 40147290623339.89

# %%
cov_banking=Odisha['GAV Banking '].cov(Odisha['GDP/Capita'])
cov_banking
# Out:
# 1404176823045.082

# %%
cov_banking=WB['GAV Banking'].cov(WB['GDP/Capita'])
cov_banking
# Out:
# 1867090992676.7732

# %%
cov_Services=Odisha['GAV Services'].cov(Odisha['GDP/Capita'])
cov_Services
# Out:
# 13656652481799.453

# %%
cov_Services=WB['GAV Services'].cov(WB['GDP/Capita'])
cov_Services
# Out:
# 60897276459461.19

# %%
# Correlation

corr_Agri=Odisha['GAV Agri'].corr(Odisha['GDP/Capita'])
corr_Agri
# Out:
# 0.24150057968501892

# %%
corr_Agri=WB['GAV Agri'].corr(WB['GDP/Capita'])
corr_Agri
# Out:
# 0.962149035506501

# %%
corr_Manf=Odisha['GAV Manf'].corr(Odisha['GDP/Capita'])
corr_Manf
# Out:
# 0.975644383314957

# %%
corr_Manf=WB['GAV Manf'].corr(WB['GDP/Capita'])
corr_Manf
# Out:
# 0.9683700343915229

# %%
corr_Cons=Odisha['GAV Cons'].corr(Odisha['GDP/Capita'])
corr_Cons
# Out:
# 0.9312686316367969

# %%
corr_Cons=WB['GAV Cons'].corr(WB['GDP/Capita'])
corr_Cons
# Out:
# 0.9583242268900102

# %%
corr_banking=Odisha['GAV Banking '].corr(Odisha['GDP/Capita'])
corr_banking
# Out:
# 0.9378143851051383

# %%
corr_banking=WB['GAV Banking'].corr(WB['GDP/Capita'])
corr_banking
# Out:
# 0.4946763210922406

# %%
corr_Ind=Odisha['GAV Ind'].corr(Odisha['GDP/Capita'])
corr_Ind
# Out:
# 0.9871399832483465

# %%
corr_Ind=WB['GAV Ind'].corr(WB['GDP/Capita'])
corr_Ind
# Out:
# 0.9899648619754567

# %%
corr_Services=Odisha['GAV Services'].corr(Odisha['GDP/Capita'])
corr_Services
# Out:
# 0.9783635614993048

# %%
corr_Services=WB['GAV Services'].corr(WB['GDP/Capita'])
corr_Services
# Out:
# 0.9966271755064561

# %%
#Plotting grpah of year vs GDP
Odisha.plot.bar(x='Year',y='GDP/Capita')
plt.xlabel('year')
plt.ylabel('GDP/Capita')
# Out:
# Text(0, 0.5, 'GDP/Capita')

# %%
#Plotting grpah of year vs GDP
WB.plot.bar(x='Year',y='GDP/Capita')
plt.xlabel('year')
plt.ylabel('GDP/Capita')
# Out:
# Text(0, 0.5, 'GDP/Capita')

# %%
x=Odisha[['GAV Agri','GAV Manf','GAV Ind','GAV Services','GAV Cons','GAV Banking ']]
y=Odisha['GDP/Capita']
regr=linear_model.LinearRegression()
regr.fit(x,y)
print(regr.coef_)
OD_coeff=regr.coef_
OD_coeff
# Out:
# [1.28290465 0.12664264 1.10775471 0.99740004 2.02212529 3.00774659]
# array([1.28290465, 0.12664264, 1.10775471, 0.99740004, 2.02212529,
#        3.00774659])

# %%
x=WB[['GAV Agri','GAV Manf','GAV Ind','GAV Services','GAV Cons','GAV Banking']]
y=WB['GDP/Capita']
regr=linear_model.LinearRegression()
regr.fit(x,y)
print(regr.coef_)
WB_coeff=regr.coef_
WB_coeff
# Out:
# [ 0.9896839  -1.05212414  2.15585968  0.99088065 -1.23435252 -0.33724376]
# array([ 0.9896839 , -1.05212414,  2.15585968,  0.99088065, -1.23435252,
#        -0.33724376])

# %%
# Create subplots for each independent factor
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

# Plot Factor1 against GDP
axs[0].scatter(Odisha['GAV Agri'], Odisha['GDP/Capita'])
axs[0].set_xlabel('GAV Agri')
axs[0].set_ylabel('GDP/Capita')
axs[0].set_title('GAV Agri vs GDP')


axs[1].scatter(Odisha['Year'], Odisha['GAV Agri'])
axs[1].set_xlabel('Year')
axs[1].set_ylabel('GAV Agri')
axs[1].set_title('Year vs GAV Agri')
# Out:
# Text(0.5, 1.0, 'Year vs GAV Agri')

# %%
# Create subplots for each independent factor
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

# Plot Factor1 against GDP
axs[0].scatter(WB['GAV Agri'], WB['GDP/Capita'])
axs[0].set_xlabel('GAV Agri')
axs[0].set_ylabel('GDP/Capita')
axs[0].set_title('GAV Agri vs GDP')


axs[1].scatter(WB['Year'], WB['GAV Agri'])
axs[1].set_xlabel('Year')
axs[1].set_ylabel('GAV Agri')
axs[1].set_title('Year vs GAV Agri')
# Out:
# Text(0.5, 1.0, 'Year vs GAV Agri')

# %%
# Create subplots for each independent factor
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

# Plot Factor1 against GDP
axs[0].scatter(Odisha['GAV Services'], Odisha['GDP/Capita'])
axs[0].set_xlabel('GAV Services')
axs[0].set_ylabel('GDP/Capita')
axs[0].set_title('GAV Services vs GDP')


axs[1].scatter(Odisha['Year'], Odisha['GAV Services'])
axs[1].set_xlabel('Year')
axs[1].set_ylabel('GAV Services')
axs[1].set_title('Year vs GAV Services')
# Out:
# Text(0.5, 1.0, 'Year vs GAV Services')

# %%
# Create subplots for each independent factor
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

# Plot Factor1 against GDP
axs[0].scatter(WB['GAV Services'], WB['GDP/Capita'])
axs[0].set_xlabel('GAV Services')
axs[0].set_ylabel('GDP/Capita')
axs[0].set_title('GAV Services vs GDP')


axs[1].scatter(WB['Year'], WB['GAV Services'])
axs[1].set_xlabel('Year')
axs[1].set_ylabel('GAV Services')
axs[1].set_title('Year vs GAV Services')
# Out:
# Text(0.5, 1.0, 'Year vs GAV Services')

# %%
# Set the x-axis values (assuming you have categorical data for the x-axis)
x = Odisha['Year']

# Set the width of each bar
bar_width = 0.35

# Plotting bars for df1
plt.bar(x, Odisha['GDP/Capita'], width=bar_width, label='Data Frame 1')

# Plotting bars for df2 with an offset
plt.bar(x + bar_width, WB['GDP/Capita'], width=bar_width, label='Data Frame 2')

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Y-axis')
plt.title('Comparison of Data Frames')

# Set the x-axis tick labels
#plt.xticks(x + bar_width / 2, maha['x'])

# Display legend
plt.legend()

# Show the plot
plt.show()

# %%
# Set the x-axis values (assuming you have categorical data for the x-axis)
x = Odisha['Year']

# Set the width of each bar
bar_width = 0.35

# Plotting bars for df1
plt.bar(x, Odisha['GAV Agri'], width=bar_width, label='Data Frame 1')

# Plotting bars for df2 with an offset
plt.bar(x + bar_width, WB['GAV Agri'], width=bar_width, label='Data Frame 2')

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Agri Sector')
plt.title('Comparison of Data Frames')

# Set the x-axis tick labels
#plt.xticks(x + bar_width / 2, maha['x'])

# Display legend
plt.legend()

# Show the plot
plt.show()

# %%
# Set the x-axis values (assuming you have categorical data for the x-axis)
x = Odisha['Year']

# Set the width of each bar
bar_width = 0.35

# Plotting bars for df1
plt.bar(x, Odisha['GAV Manf'], width=bar_width, label='Data Frame 1')

# Plotting bars for df2 with an offset
plt.bar(x + bar_width, WB['GAV Manf'], width=bar_width, label='Data Frame 2')

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Manf Sector')
plt.title('Comparison of Data Frames')

# Set the x-axis tick labels
#plt.xticks(x + bar_width / 2, maha['x'])

# Display legend
plt.legend()

# Show the plot
plt.show()

# %%
# Set the x-axis values (assuming you have categorical data for the x-axis)
x = Odisha['Year']

# Set the width of each bar
bar_width = 0.35

# Plotting bars for df1
plt.bar(x, Odisha['GAV Cons'], width=bar_width, label='Data Frame 1')

# Plotting bars for df2 with an offset
plt.bar(x + bar_width, WB['GAV Cons'], width=bar_width, label='Data Frame 2')

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Cons Sector')
plt.title('Comparison of Data Frames')

# Set the x-axis tick labels
#plt.xticks(x + bar_width / 2, maha['x'])

# Display legend
plt.legend()

# Show the plot
plt.show()

# %%
# Set the x-axis values (assuming you have categorical data for the x-axis)
x = Odisha['Year']

# Set the width of each bar
bar_width = 0.35

# Plotting bars for df1
plt.bar(x, Odisha['GAV Banking '], width=bar_width, label='Data Frame 1')

# Plotting bars for df2 with an offset
plt.bar(x + bar_width, WB['GAV Banking'], width=bar_width, label='Data Frame 2')

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Banking Sector')
plt.title('Comparison of Data Frames')

# Set the x-axis tick labels
#plt.xticks(x + bar_width / 2, maha['x'])

# Display legend
plt.legend()

# Show the plot
plt.show()

# %%
# Set the x-axis values (assuming you have categorical data for the x-axis)
x = Odisha['Year']

# Set the width of each bar
bar_width = 0.35

# Plotting bars for df1
plt.bar(x, Odisha['GAV Services'], width=bar_width, label='Data Frame 1')

# Plotting bars for df2 with an offset
plt.bar(x + bar_width, WB['GAV Services'], width=bar_width, label='Data Frame 2')

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Services Sector')
plt.title('Comparison of Data Frames')

# Set the x-axis tick labels
#plt.xticks(x + bar_width / 2, maha['x'])

# Display legend
plt.legend()

# Show the plot
plt.show()

# %%
# Set the x-axis values (assuming you have categorical data for the x-axis)
x = maha['Year']

# Set the width of each bar
bar_width = 0.35

# Plotting bars for df1
plt.bar(x, maha['GAV Ind'], width=bar_width, label='Data Frame 1')

# Plotting bars for df2 with an offset
plt.bar(x + bar_width, MP['GAV Ind'], width=bar_width, label='Data Frame 2')

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Ind Sector')
plt.title('Comparison of Data Frames')

# Set the x-axis tick labels
#plt.xticks(x + bar_width / 2, maha['x'])

# Display legend
plt.legend()

# Show the plot
plt.show()

# %%
import seaborn as sns
import pandas as pd


# Select the variables you want to include in the scatterplot matrix
variables =['GAV Agri','GAV Manf','GAV Ind','GAV Services','GAV Cons','GAV Banking ','GDP/Capita']

# Create a subset of the data frame with the selected variables
subset_df = Odisha[variables]

# Create the scatterplot matrix
sns.pairplot(subset_df)

# Show the plot
plt.show()

# %%
import seaborn as sns
import pandas as pd


# Select the variables you want to include in the scatterplot matrix
variables =['GAV Agri','GAV Manf','GAV Ind','GAV Services','GAV Cons','GAV Banking','GDP/Capita']

# Create a subset of the data frame with the selected variables
subset_df = WB[variables]

# Create the scatterplot matrix
sns.pairplot(subset_df)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have a list or array 'coefficients' containing the coefficients
# and a list or array 'variables' containing the names of the independent variables

# Create a bar plot of the coefficients
variables=['GAV Agri','GAV Manf','GAV Ind','GAV Services','GAV Cons','GAV Banking ']
plt.figure(figsize=(10, 6))
plt.bar(variables, OD_coeff)
plt.xlabel('Independent Variables')
plt.ylabel('Coefficients')
plt.title('Coefficients of Multiple Regression')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have a list or array 'coefficients' containing the coefficients
# and a list or array 'variables' containing the names of the independent variables

# Create a bar plot of the coefficients
variables=['GAV Agri','GAV Manf','GAV Ind','GAV Services','GAV Cons','GAV Banking ']
plt.figure(figsize=(10, 6))
plt.bar(variables, WB_coeff)
plt.xlabel('Independent Variables')
plt.ylabel('Coefficients')
plt.title('Coefficients of Multiple Regression')
plt.xticks(rotation=45)
plt.show()

# %%
# Assuming you have a pandas DataFrame named 'df' containing your data

# Calculate the correlation matrix
corr_matrix = Odisha.corr()

# Create a heatmap using the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Calculate the correlation matrix
corr_matrix = WB.corr()

# Create a heatmap using the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
